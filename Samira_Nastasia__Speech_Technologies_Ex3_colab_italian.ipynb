# %% [markdown]
# # Download data
#
# To get the download link go to https://commonvoice.mozilla.org/de/datasets
#
# * Choose the language at the top
# * Mark which dataste you want to download --> Common Voice Corpus 11.0
# * Pretend to save it locally, but pause it, after it started! You can copy the link in your download manager.
# *Right click on the link and copy it. Paste it to the wget call in colab.

# %%
# !wget "https://storage.googleapis.com/common-voice-prod-prod-datasets/cv-corpus-11.0-2022-09-21/cv-corpus-11.0-2022-09-21-it.tar.gz?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-prod%40moz-fx-common-voice-prod.iam.gserviceaccount.com%2F20240617%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240617T185445Z&X-Goog-Expires=43200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." -O /content/cv_11.tar.gz
# Out:
# --2024-06-17 19:34:43--  https://storage.googleapis.com/common-voice-prod-prod-datasets/cv-corpus-11.0-2022-09-21/cv-corpus-11.0-2022-09-21-it.tar.gz?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-prod%40moz-fx-common-voice-prod.iam.gserviceaccount.com%2F20240617%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240617T185445Z&X-Goog-Expires=43200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 2607:f8b0:4023:c0b::cf, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8784083327 (8.2G) [application/octet-stream]
# Saving to: ‘/content/cv_11.tar.gz’
#
# /content/cv_11.tar. 100%[===================>]   8.18G   121MB/s    in 77s
#
# 2024-06-17 19:36:00 (109 MB/s) - ‘/content/cv_11.tar.gz’ saved [8784083327/8784083327]

# %%
# !tar -xvzf /content/cv_11.tar.gz -C /content/
# Out:
# Streaming output truncated to the last 5000 lines.
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331655.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331656.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331677.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331678.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331679.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331680.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331681.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331682.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331683.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331684.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331685.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331686.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331692.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331693.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331694.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331695.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331696.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331697.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331698.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331699.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331700.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331701.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331702.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331703.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331704.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331705.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331706.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331707.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331708.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331709.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331710.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331711.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331732.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331733.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331734.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331735.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331736.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331757.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331758.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331759.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331760.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331761.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331764.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331767.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331769.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331770.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331771.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331772.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331773.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331774.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331775.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32331776.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32334691.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32334694.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32334696.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32334698.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32334700.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339738.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339739.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339745.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339746.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339747.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339748.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339754.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339760.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32339761.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32345774.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32345777.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32345780.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32345782.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32345783.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32348999.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349000.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349001.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349002.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349003.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349033.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349034.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349035.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349036.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32349038.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363624.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363625.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363627.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363628.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363630.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363657.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363658.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363659.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363661.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363664.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363697.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363698.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363699.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363700.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363701.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363732.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363733.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363734.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363735.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363736.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363756.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363757.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363758.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363760.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363761.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363782.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363783.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363784.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363785.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363786.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363837.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363838.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363839.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363840.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363841.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363842.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363843.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363844.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363845.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363846.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363852.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363853.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363854.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363855.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32363856.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364378.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364379.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364380.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364381.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364382.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364420.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364421.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364422.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364423.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32364424.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366212.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366213.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366214.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366215.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366216.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366227.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366228.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366229.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366230.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366231.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366242.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366243.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366244.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366245.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366246.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366545.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366546.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366547.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366548.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366549.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366760.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366761.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366762.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366763.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366764.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366814.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366815.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366816.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366817.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366818.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366839.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366840.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366841.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366842.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366843.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366859.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366860.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366861.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366862.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366863.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366894.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366895.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366896.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366897.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366898.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366937.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366938.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366939.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366940.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32366941.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367227.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367228.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367229.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367230.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367241.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367242.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367243.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367244.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367245.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367256.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367257.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367258.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367259.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367260.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367280.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367282.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367283.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367284.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367285.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367321.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367322.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367323.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367324.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367325.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367332.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367333.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367334.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367335.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367336.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367355.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367356.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367357.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367358.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367359.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367403.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367404.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367406.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367407.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367408.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367416.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367417.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367418.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367419.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367420.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367431.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367432.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367433.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367434.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367435.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367456.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367457.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367458.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367459.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367460.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367461.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367462.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367463.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367464.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367465.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367471.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367472.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367473.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367474.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367475.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367495.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367496.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367497.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367498.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367499.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367505.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367506.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367507.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367508.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367509.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367511.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367512.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367515.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367517.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367518.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367520.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367521.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367522.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367523.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367525.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367530.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367531.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367532.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367533.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367534.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367536.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367537.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367538.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367539.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367540.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367541.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367542.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367543.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367544.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367545.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367546.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367547.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367548.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367549.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367550.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367551.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367552.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367553.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367554.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367555.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367556.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367557.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367558.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367559.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367560.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367561.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367562.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367563.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367564.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367565.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367566.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367567.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367568.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367569.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367570.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367955.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367956.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367957.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367958.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367959.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367980.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367981.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367982.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367983.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32367984.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368000.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368001.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368002.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368003.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368004.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368020.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368021.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368022.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368023.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32368024.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370222.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370223.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370224.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370225.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370226.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370262.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370263.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370264.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370265.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370266.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370290.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370291.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370292.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370293.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370294.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370310.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370311.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370312.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370313.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370314.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370335.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370336.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370337.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370338.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370339.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370420.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370421.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370422.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370423.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370424.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370425.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370426.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370427.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370428.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32370429.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32371131.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32371132.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32371133.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32371134.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32371135.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377034.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377035.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377036.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377037.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377038.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377039.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377040.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377041.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377042.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377043.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377044.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377045.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377046.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377047.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377048.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377049.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377050.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377051.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377052.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377053.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377054.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377055.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377056.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377057.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377058.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377074.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377075.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377076.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377077.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32377078.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32379404.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32379405.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32379406.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32379408.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380443.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380444.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380445.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380446.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380447.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380477.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380478.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380479.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380480.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380481.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380547.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380548.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380549.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380550.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380551.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380602.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380603.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380604.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380605.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380606.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380627.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380628.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380629.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380630.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380631.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32380716.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382400.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382401.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382402.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382403.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382404.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382425.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382426.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382427.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382428.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382429.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382503.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382504.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382505.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382506.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382507.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382518.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382519.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382520.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382521.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32382522.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383005.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383006.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383007.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383008.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383009.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383010.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383011.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383012.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383013.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383014.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383079.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383080.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383081.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383082.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383083.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383114.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383115.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383116.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383117.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383118.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383144.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383145.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383146.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383147.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383148.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383178.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383179.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383180.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383182.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383183.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383218.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383219.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383221.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383223.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383225.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383239.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383240.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383241.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383242.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383243.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383333.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383334.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383335.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383336.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383337.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383357.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383358.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383359.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383360.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383361.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383379.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383380.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383381.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383382.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383383.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383384.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383385.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383386.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383388.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32383390.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394807.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394808.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394809.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394810.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394811.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394817.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394818.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394819.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394820.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394821.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394827.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394828.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394829.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394830.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394831.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394832.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394833.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394834.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394835.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394836.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394842.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394843.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394844.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394845.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394846.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394847.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394848.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394849.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394850.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394851.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394857.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394858.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394859.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394860.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394861.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394867.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394868.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394869.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394870.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32394871.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398180.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398181.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398182.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398183.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398184.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398190.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398191.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398192.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398193.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398194.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398195.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398196.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398197.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398198.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398199.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398205.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398206.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398207.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398208.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398209.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398220.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398221.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398222.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398223.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398224.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398230.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398231.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398232.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398233.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398234.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398804.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398805.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398806.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398807.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398808.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398814.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398815.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398816.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398817.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398818.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398824.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398825.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398826.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398827.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398828.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398839.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398840.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398841.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398842.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398843.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398849.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398850.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398851.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398852.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398853.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398859.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398860.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398861.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398862.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398863.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398868.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398869.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398870.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398871.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398872.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398873.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398874.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398875.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398876.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398877.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398903.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398904.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398905.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398906.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32398907.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32406264.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32406265.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32406266.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32406267.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32406268.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417471.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417472.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417473.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417474.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417475.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417496.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417497.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417498.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417499.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417500.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417702.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417703.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417704.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417705.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417706.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417723.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417724.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417725.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417726.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32417727.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419152.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419153.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419154.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419155.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419156.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419396.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32419397.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425864.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425870.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425879.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425882.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425883.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425884.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425890.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425896.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425897.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425906.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425914.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425920.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425928.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425937.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425938.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425939.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425945.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425956.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425962.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425963.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425974.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425984.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425991.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425992.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32425993.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426007.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426010.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426014.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426022.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426945.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426946.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426947.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426948.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426954.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426955.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426956.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426957.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426958.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32426959.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32431286.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32431287.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453719.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453721.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453722.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453730.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453734.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453908.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453910.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453912.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453914.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32453916.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32454084.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32454086.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32454089.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32454091.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32454094.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456785.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456786.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456787.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456788.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456789.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456796.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456799.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456807.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456810.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456812.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456860.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456861.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456862.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456863.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456864.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456875.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456877.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456878.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456879.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456880.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456904.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456905.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456906.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456907.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456908.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456929.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456930.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456931.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456936.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32456939.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460865.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460866.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460867.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460868.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460869.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_32460870.mp3
# ...
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892579.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892585.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892591.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892597.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892598.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892619.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892620.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892631.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892634.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892640.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892643.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892644.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892650.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892651.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892662.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892668.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892674.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892680.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892683.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892687.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892693.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892699.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892709.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892711.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892716.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892722.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892726.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892739.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892740.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892741.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892747.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892763.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892769.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892780.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892786.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892791.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892792.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892807.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892809.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892815.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892822.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892830.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892841.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892844.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892857.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892866.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892869.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892883.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892889.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892902.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892913.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892922.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892926.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892927.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892928.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892934.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892940.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892941.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892952.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892963.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892964.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892965.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892966.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892972.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892983.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892989.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892990.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34892992.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893002.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893008.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893009.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893010.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893011.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893012.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893018.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893019.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893030.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893031.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893034.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893040.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893041.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893042.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893061.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893064.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893065.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893070.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893077.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893081.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893094.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893102.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893104.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893105.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893118.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893129.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893130.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893136.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893141.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893148.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893153.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893154.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893175.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893176.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893182.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893186.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893189.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893190.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893196.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893202.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893208.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893218.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893233.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893234.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893235.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893241.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893243.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893244.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893245.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893253.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893256.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893262.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893268.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893269.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893270.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893276.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893282.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893298.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893308.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893315.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34893316.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34896619.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34896629.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34896635.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34896637.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34896642.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907806.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907807.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907808.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907809.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907810.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907836.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907837.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907838.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907839.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907840.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907917.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907918.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907919.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907920.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907921.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907992.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907993.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907994.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907995.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34907996.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920041.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920123.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920124.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920125.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920126.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920127.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920915.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920916.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920917.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920918.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920919.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920930.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920931.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920932.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920933.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920934.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920945.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920946.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920947.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920948.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920949.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920965.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920966.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920967.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920968.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920969.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920979.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920980.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920981.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920982.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34920983.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921030.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921032.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921033.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921035.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921036.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921241.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921243.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921244.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921246.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921247.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921268.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921269.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921270.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921271.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921272.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921317.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921318.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921319.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921320.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921321.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921337.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921338.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921339.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921340.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921341.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921366.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921367.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921368.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921369.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921370.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921401.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921402.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921403.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921404.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921405.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921426.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921427.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921428.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921429.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921430.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921456.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921457.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921458.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921459.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921460.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921496.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921497.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921498.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921499.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921500.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921546.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921547.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921548.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921549.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921550.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921580.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921581.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921582.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921583.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921584.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921620.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921621.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921623.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921625.mp3
# cv-corpus-11.0-2022-09-21/it/clips/common_voice_it_34921627.mp3

# %%
# !rm cv_11.tar.gz

# %%
# !git clone https://github.com/lorgu/accent-recog-slt2022
# Out:
# Cloning into 'accent-recog-slt2022'...
# remote: Enumerating objects: 566, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 566 (delta 167), reused 143 (delta 100), pack-reused 337
# Receiving objects: 100% (566/566), 2.66 MiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (370/370), done.

# %%
# %cd accent-recog-slt2022/
# Out:
# /content/accent-recog-slt2022

# %%
# !python -m pip -q install -r /content/accent-recog-slt2022/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.0/499.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 65.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 72.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 86.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 71.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 981.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 53.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 48.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.4.26 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# jaxlib 0.4.26+cuda12.cudnn89 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.11.0 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 1.11.0 which is incompatible.

# %%
# !pip -q install torch==1.12.1+cu116 torchvision==0.13.1+cu116 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 GB 559.8 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 63.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 95.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.12.1+cu116 which is incompatible.

# %%
# !pip -q install -U datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.12.1+cu116 which is incompatible.

# %% [markdown]
# # Selecting the Accents and Preparing the Training Files (csv)

# %%
"""
Data preparation of CommonAccent dataset for Accent classification (Italian).
(Recipe that uses CV version 11.0)
Download: https://commonvoice.mozilla.org/en/datasets

Author
------
 * Juan Pablo Zuluaga 2023
"""

import csv
import logging
import os
import argparse
import re
import warnings
import unicodedata

import pandas as pd
import torchaudio
from speechbrain.utils.data_utils import get_all_files
from tqdm.contrib import tzip

warnings.filterwarnings("ignore")

logger = logging.getLogger(__name__)

""" You need to first run : download_data_hf.py, to create the TSV files, and
    Then you need to select the accents you want to use in the training.

    For instance, you can do in the terminal:
    - cat /out/folder/tsv/files/* | cut -d$'\t' -f5 | sort | uniq -c | sort -n
    cat /data/vokquant/data/common_voice_de/de/* | cut -d$'\t' -f5 | sort | uniq -c | sort -n

    That command produces the count number of labeled samples with that accent.
    Select accents with at least 100 samples.
"""

_ACCENTS_EN = [
    1e4, # max 20000 samples per accent
    # "Austrian", # 104
    # "East African Khoja", # 107
    # "Dutch", # 108
    # "West Indies and Bermuda (Bahamas, Bermuda, Jamaica, Trinidad)", # 282
    # "Welsh English", # 623
    "Malaysian English", # 1004
    # "Liverpool English,Lancashire English,England English", # 2571
    "Singaporean English", # 2792
    "Hong Kong English", # 2951
    "Filipino", # 4030
    "Southern African (South Africa, Zimbabwe, Namibia)", # 4270
    "New Zealand English", # 4960
    "Irish English", # 6339
    # "Northern Irish", # 6862
    "Scottish English", # 10817
    "Australian English", # 33335
    "German English,Non native speaker", # 41258
    "Canadian English", # 45640
    "England English", # 75772
    "India and South Asia (India, Pakistan, Sri Lanka)", # 79043
    "United States English", # 249284
]
_ACCENTS_FR = [
    1e4, # max 10000 samples per accent
    # "Français d’Algérie", # 319
    # "Français d’Allemagne", # 355
    # "Français du Bénin", # 823
    # "Français de La Réunion", # 884
    # "Français des États-Unis", # 898
    "Français de Suisse", # 3608
    "Français de Belgique", # 6509
    "Français du Canada", # 8073
    "Français de France", # 342921
]
# _ACCENTS_DE = [
#     1e4, # max 10000 samples per accent
#     "Italienisch Deutsch", # 947
#     "Schweizerdeutsch", # 9891
#     "Österreichisches Deutsch", # 16066
#     "Nordrhein-Westfalen,Bundesdeutsch, Hochdeutsch,Deutschland Deutsch", # 50843
#     "Deutschland Deutsch", # 252709
# ]

_ACCENTS_DE = [
    1e3, # max 1000 samples per accent
    "Ungarisch Deutsch", # 113
    "Griechisch Deutsch", # 118
    "Kanadisches Deutsch", # 122
    "Britisches Deutsch", # 134
    "Ruhrpott Deutsch", # 167
    "Russisch Deutsch", # 232
    "Amerikanisches Deutsch", # 236
]

_ACCENTS_IT = [
    1e4, # max 10000 samples per accent
    "Emiliano", # 151
    "Meridionale", # 193
    "Veneto", # 1508
    "Tendente al siculo, ma non marcato", # 2175
    "Basilicata,trentino", # 2297
]
_ACCENTS_ES = [
    1e4, # max 10000 samples per accent
    # "España: Islas Canarias", # 1326
    "Chileno: Chile, Cuyo", # 4285
    # "América central", # 6031
    "Caribe: Cuba, Venezuela, Puerto Rico, República Dominicana, Panamá, Colombia caribeña, México caribeño, Costa del golfo de México", # 8329
    # "España: Centro-Sur peninsular (Madrid, Toledo, Castilla-La Mancha)", # 8683
    "Rioplatense: Argentina, Uruguay, este de Bolivia, Paraguay", # 11162
    "Andino-Pacífico: Colombia, Perú, Ecuador, oeste de Bolivia y Venezuela andina", # 12997
    "México", # 26136
    # "España: Norte peninsular (Asturias, Castilla y León, Cantabria, País Vasco, Navarra, Aragón, La Rioja, Guadalajara, Cuenca)", # 30588
    "España: Sur peninsular (Andalucia, Extremadura, Murcia)", # 38251
]


def prepare_common_accent(
        data_folder,
        save_folder,
        accented_letters=False,
        language='it',
        skip_prep=False,
    ):
    """
    Prepares the csv files for the CommonAccent dataset for Accent Classification.
    Download: https://commonvoice.mozilla.org/en/datasets

    Arguments
    ---------
    data_folder : str
        Path to the folder where the CommonAccent dataset for Accent Classification is stored.
        This path should include the multi: /datasets/CommonAccent
    save_folder : str
        The directory where to store the csv files.
    max_duration : int, optional
        Max duration (in seconds) of training uterances.
    accented_letters : bool, optional
        Defines if accented letters will be kept as individual letters or
        transformed to the closest non-accented letters.
    language: str
        Specify the language for text normalization.
    skip_prep: bool
        If True, skip data preparation.

    Example
    -------
    >>> from recipes.CommonAccent.common_accent_prepare import prepare_common_accent
    from common_accent_prepare import prepare_common_accent
    >>> data_folder = '/datasets/CommonAccent'
    data_folder = '/nas/projects/vokquant/data/common_voice_de/'
    >>> save_folder = 'exp/CommonAccent_exp'
    save_folder = '/nas/projects/vokquant/data/common_voice_de/experiment'
    >>> prepare_common_accent(\
            data_folder,\
            save_folder,\
            skip_prep=False\
        )
    """

    if skip_prep:
        return

    # Setting the save folder
    os.makedirs(save_folder, exist_ok=True)

    # Setting ouput files
    save_csv_train = os.path.join(save_folder, "train.csv")
    save_csv_dev = os.path.join(save_folder, "dev.csv")
    save_csv_test = os.path.join(save_folder, "test.csv")

    # If csv already exists, we skip the data preparation
    if skip(save_csv_train, save_csv_dev, save_csv_test):
        csv_exists = " already exists, skipping data preparation!"
        msg = save_csv_train + csv_exists
        logger.info(msg)
        msg = save_csv_dev + csv_exists
        logger.info(msg)
        msg = save_csv_test + csv_exists
        logger.info(msg)

        return

    # Additional checks to make sure the data folder contains Common Accent
    check_common_accent_folder(data_folder, language=language)

    # Audio files extensions
    extension = [".mp3"]

    # Create the signal list of train, dev, and test sets.
    data_split = create_sets(data_folder, extension, language=language)

    # Creating csv files for training, dev and test data
    create_csv(wav_list=data_split["train"], csv_file=save_csv_train)
    create_csv(wav_list=data_split["dev"], csv_file=save_csv_dev)
    create_csv(wav_list=data_split["test"], csv_file=save_csv_test)



def skip(save_csv_train, save_csv_dev, save_csv_test):
    """
    Detects if the CommonAccent data preparation for Accent Classification has been already done.

    If the preparation has been done, we can skip it.

    Returns
    -------
    bool
        if True, the preparation phase can be skipped.
        if False, it must be done.
    """

    # Checking folders and save options
    skip = (
        os.path.isfile(save_csv_train)
        and os.path.isfile(save_csv_dev)
        and os.path.isfile(save_csv_test)
    )

    return skip

import ipdb
def create_sets(data_folder, extension, language='it'):
    """
    Creates lists for train, dev and test sets with data from the data_folder

    Arguments
    ---------
    data_folder : str
        Path of the CommonAccent dataset.
    extension: list of file extentions
        List of strings with file extentions that correspond to the audio files
        in the CommonAccent dataset

    Returns
    -------
    dictionary containing train, dev, and test splits.
    """
    # get the ACCENT dictionary from accent_configuration
    if language == "en":
        ACCENTS = _ACCENTS_EN
    elif language == "it":
        ACCENTS = _ACCENTS_IT
    elif language == "de":
        ACCENTS = _ACCENTS_DE
    elif language == "fr":
        ACCENTS = _ACCENTS_FR
    elif language == "es":
        ACCENTS = _ACCENTS_ES

    # get the max_samples_per_accent from the list:
    max_samples_per_accent = ACCENTS[0]
    max_samples_per_accent = 2e3

    # accent counter to balance the datasets:
    accent_counter = { acc_id: 0 for acc_id in ACCENTS}

    # Datasets initialization
    datasets = {"train", "validation", "test"}

    # Get the list of accents from the dataset folder
    msg = f"Loading the data of train/validation/test sets!"
    logger.info(msg)

    accent_wav_list = []

    # Fill the train, dev and test datasets with audio filenames
    for dataset in datasets:
        curr_csv_file = os.path.join(data_folder, language, dataset + ".tsv")
        with open(curr_csv_file, "r") as file:
            csvreader = csv.reader(file, delimiter='\t')
            for row in csvreader:
                # print(row[7])
                accent = row[7]  # accent information is in this field

                # if accent is part of the accents (top file dict), then, we add it:
                if accent in ACCENTS:

                    # check if we have reached the max_samples per accent:
                    if accent_counter[accent] > max_samples_per_accent:
                        continue
                    utt_id = row[1].split('.mp3')[0]
                    wav_path = "/content/cv-corpus-11.0-2022-09-21/" + language + "/clips/" + row[1]
                    print_folders = False
                    if print_folders == True:
                        print("utt_id: ", utt_id)
                        print("wav_path", wav_path)

                    # get transcript and clean it!
                    transcript = clean_transcript(row[2], language=language)
                    # short transcript, remove:
                    if len(transcript.split()) < 1: continue

                    # also we clean the label, which will be used during training
                    clean_accent = clean_transcript(accent, language=language)

                    # Peeking at the signal (to retrieve duration in seconds)
                    if os.path.isfile(wav_path):
                        info = torchaudio.info(wav_path)
                        audio_duration = info.num_frames / info.sample_rate
                    else:
                        msg = "\tError loading: %s" % (str(len(wav_path)))
                        logger.info(msg)
                        continue
                    # append to list
                    accent_wav_list.append([utt_id, wav_path, transcript, audio_duration, clean_accent])

                    # update the accent counter
                    accent_counter[accent] += 1

    # Split the data in train/dev/test balanced:
    df = pd.DataFrame(
        accent_wav_list, columns=["utt_id", "path", "transcript", "duration", "accent"]
    )

    df_train, df_dev, df_test = [], [], []

    # We need to create the train/dev/test sets, with equal samples for dev and test sets
    all_accents = df.accent.unique()

    # for loop to go over each accent and get the values
    for accent in all_accents:
        condition = df["accent"] == accent

        # subset with only the given 'accent'
        df_with_accent = df[condition]
        df_size = int(df_with_accent.accent.count())

        # if there are less than 500 samples, we put 20% for dev and test sets, 60% for train
        n_samples = 100 if df_size > 500 else int(df_size * 0.2)

        # get and append the first 100 values for dev/test sets, for train, we use the rest
        df_dev.append(df_with_accent.iloc[0:n_samples])
        df_test.append(df_with_accent.iloc[n_samples : n_samples * 2])
        df_train.append(df_with_accent.iloc[n_samples * 2 :])


    # create the object with the pandas DataFrames to output:
    accent_wav_list = {}
    accent_wav_list["train"] = pd.concat(df_train)
    accent_wav_list["dev"] = pd.concat(df_dev)
    accent_wav_list["test"] = pd.concat(df_test)

    msg = "Data successfully loaded!"
    logger.info(msg)

    return accent_wav_list


def create_csv(wav_list, csv_file):
    """
    Creates the csv file given a list of wav files.

    Arguments
    ---------
    wav_list : list of str
        The list of wav files.
    csv_file : str
        The path of the output json file
    """

    # Adding some Prints
    msg = f"Creating csv lists in {csv_file} ..."
    logger.info(msg)

    csv_lines = []

    # Start processing lines
    total_duration = 0.0

    # Starting index
    idx = 0
    for sample in wav_list.iterrows():

        # get some data from the file (CommonVoice is MP3)
        utt_id = sample[1][0]
        wav_path = sample[1][1]
        wav_format = wav_path.split(os.path.sep)[-1].split(".")[-1]
        transcript = sample[1][2]
        accent = sample[1][4]
        audio_duration = sample[1][3]

        # Create a row with whole utterences
        csv_line = [
            idx,  # ID
            utt_id,  # Utterance ID
            wav_path,  # File name
            wav_format,  # File format
            transcript, # transcript
            str("%.3f" % audio_duration),  # Duration (sec)
            accent,  # Accent
        ]

        # Adding this line to the csv_lines list
        csv_lines.append(csv_line)

        # Increment index
        idx += 1

        # update total duration
        total_duration += audio_duration


    # CSV column titles
    csv_header = ["ID", "utt_id", "wav", "wav_format", "text", "duration", "accent"]

    # Add titles to the list at indexx 0
    csv_lines.insert(0, csv_header)

    # Writing the csv lines
    with open(csv_file, mode="w", encoding="utf-8") as csv_f:
        csv_writer = csv.writer(
            csv_f, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL
        )

        for line in csv_lines:
            csv_writer.writerow(line)

    # Final prints
    msg = f"{csv_file} sucessfully created!"
    logger.info(msg)
    msg = f"Number of samples: {len(wav_list)}."
    logger.info(msg)
    msg = f"Total duration: {round(total_duration / 3600, 2)} hours."
    logger.info(msg)


def check_common_accent_folder(data_folder, language='it'):
    """
    Check if the data folder actually contains the CommonAccent dataset.

    If not, raises an error.

    Returns
    -------
    None

    Raises
    ------
    FileNotFoundError
        If data folder doesn't contain at least two accents.
    """

    # Checking if at least two accents are present in the data
    files = set(os.listdir(os.path.join(data_folder, language)))

    if "train.tsv" not in files:
        err_msg = f"{data_folder}/{language} must have at least 'train.tsv' file in it."
        raise FileNotFoundError(err_msg)


def main():
    # read input from CLI, you need to run it from the command lind
    parser = argparse.ArgumentParser()

    # reporting vars
    parser.add_argument(
        "--language",
        type=str,
        default='it',
        help="Language to load",
    )
    parser.add_argument(
        "cv_folder",
        help="path of the input folder, where CV dataset is stored (files in TSV format)",
    )
    parser.add_argument(
        "output_folder",
        help="path of the output folder to store the csv files for each split",
    )
    # parse the arguments and run the preparation
    args = parser.parse_args()
    prepare_common_accent(args.cv_folder, args.output_folder, language=args.language)

def clean_transcript(words, language='it', accented_letters=False):
    """ function to clean the input transcript
        input:
        words: transcript
        language: language of the sample, default=en
        accented_letters: whether to remove accented_letters
    """
    def unicode_normalisation(text):
        try:
            text = unicode(text, "utf-8")
        except NameError:  # unicode is a default on python 3
            pass
        return str(text)

    # Unicode Normalization
    words = unicode_normalisation(words)

    # !! Language specific cleaning !!
    # Important: feel free to specify the text normalization
    # corresponding to your alphabet.

    def strip_accents(text):
        text = (
            unicodedata.normalize("NFD", text)
            .encode("ascii", "ignore")
            .decode("utf-8")
        )
        return str(text)

    if language in ["en", "fr", "it", "rw"]:
        words = re.sub(
            "[^’'A-Za-z0-9À-ÖØ-öø-ÿЀ-ӿéæœâçèàûî]+", " ", words
        ).upper()

    if language == "de":
        # this replacement helps preserve the case of ß
        # (and helps retain solitary occurrences of SS)
        # since python's upper() converts ß to SS.
        words = words.replace("ß", "0000ß0000")
        words = re.sub("[^’'A-Za-z0-9öÖäÄüÜß]+", " ", words).upper()
        words = words.replace("'", " ")
        words = words.replace("’", " ")
        words = words.replace(
            "0000SS0000", "ß"
        )  # replace 0000SS0000 back to ß as its initial presence in the corpus

    if language == "fr":
        # Replace J'y D'hui etc by J_ D_hui
        words = words.replace("'", " ")
        words = words.replace("’", " ")

    elif language == "ar":
        HAMZA = "\u0621"
        ALEF_MADDA = "\u0622"
        ALEF_HAMZA_ABOVE = "\u0623"
        letters = (
            "ابتةثجحخدذرزسشصضطظعغفقكلمنهويىءآأؤإئ"
            + HAMZA
            + ALEF_MADDA
            + ALEF_HAMZA_ABOVE
        )
        words = re.sub("[^" + letters + " ]+", "", words).upper()
    elif language == "ga-IE":
        # Irish lower() is complicated, but upper() is nondeterministic, so use lowercase
        def pfxuc(a):
            return len(a) >= 2 and a[0] in "tn" and a[1] in "AEIOUÁÉÍÓÚ"

        def galc(w):
            return w.lower() if not pfxuc(w) else w[0] + "-" + w[1:].lower()

        words = re.sub("[^-A-Za-z'ÁÉÍÓÚáéíóú]+", " ", words)
        words = " ".join(map(galc, words.split(" ")))

    # regex with predifined symbols to ignore/remove,
    chars_to_ignore_regex2 = '[\{\[\]\<\>\/\,\?\.\!\u00AC\;\:"\\%\\\]|[0-9]'

    words = re.sub(chars_to_ignore_regex2, "", words)

    # Remove accents if specified
    if not accented_letters:
        words = strip_accents(words)
        words = words.replace("'", " ")
        words = words.replace("’", " ")
        words = words.replace("\u2013", "-")
        words = words.replace("\u2014", "-")
        words = words.replace("\u2018", "'")
        words = words.replace("\u201C", "")
        words = words.replace("\u201D", "")
        words = words.replace("ñ", "n")
        words = words.replace(" - ", " ")
        words = words.replace("-", "")
        words = words.replace("'", " ")

    # Remove multiple spaces
    words = re.sub(" +", " ", words)

    # Remove spaces at the beginning and the end of the sentence
    words = words.lstrip().rstrip().upper()

    return words
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data_folder = '/content/cv-corpus-11.0-2022-09-21'
save_folder = '/content/accent-recog-slt2022/data'
language = 'it'
source_path = f"/content/cv-corpus-11.0-2022-09-21/{language}/validated.tsv"
destination_path = f"/content/cv-corpus-11.0-2022-09-21/{language}/validation.tsv"
os.system(f"cp {source_path} {destination_path}")

prepare_common_accent(data_folder, save_folder, language=language, skip_prep=False)

# %%
# %cd CommonAccent/
# !chmod +x run_accent_id_ecapa_tdnn_de.sh
# Out:
# /content/accent-recog-slt2022/CommonAccent

# %% [markdown]
# # Training 1 - Default
#
# * Before training modify the hparams files!
# Default hyperparameters:
#
# ```
# sample_rate: 16000
# number_of_epochs: 30
# batch_size: 8
# n_accents: 7 #21
# emb_dim: 192 # dimensionality of the embeddings
#
# dynamic_batching: False
# max_batch_len: 600 #
# num_bucket: 200
# num_workers: 4
#
# # Learning rates
# lr: 0.0001
# ```

# %%
# !./run_accent_id_ecapa_tdnn_de.sh
# Out:
# *** About to start the training ***
# *** output folder: /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988 ***
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988
# speechbrain.dataio.encoder - Load called, but CategoricalEncoder is not empty. Loaded data will overwrite everything. This is normal if there is e.g. an unk label defined at init.
# No pretrained model loaded
# speechbrain.core - Info: device arg overridden by command line input to: cuda:0
# speechbrain.core - 20.8M trainable parameters in AID
# speechbrain.utils.checkpoints - Would load a checkpoint here, but none found yet.
# speechbrain.utils.epoch_loop - Going into epoch 1
# Batch size: 8
# 100% 728/728 [13:37<00:00,  1.12s/it, train_loss=3.11]
# Batch size: 8
# 100% 55/55 [01:10<00:00,  1.29s/it]
# speechbrain.utils.train_logger - Epoch: 1, lr: 1.00e-04 - train loss: 3.11 - valid loss: 8.92, valid error_rate: 6.73e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-01-25+00
# speechbrain.utils.epoch_loop - Going into epoch 2
# Batch size: 8
# 100% 728/728 [13:46<00:00,  1.14s/it, train_loss=3.07]
# Batch size: 8
# 100% 55/55 [01:07<00:00,  1.24s/it]
# speechbrain.nnet.schedulers - Changing lr from 0.0001 to 9e-05
# speechbrain.utils.train_logger - Epoch: 2, lr: 1.00e-04 - train loss: 3.07 - valid loss: 15.46, valid error_rate: 7.71e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-16-25+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# Batch size: 8
# 100% 728/728 [12:28<00:00,  1.03s/it, train_loss=2.83]
# Batch size: 8
# 100% 55/55 [01:06<00:00,  1.21s/it]
# speechbrain.nnet.schedulers - Changing lr from 9e-05 to 8.1e-05
# speechbrain.utils.train_logger - Epoch: 3, lr: 9.00e-05 - train loss: 2.83 - valid loss: 11.66, valid error_rate: 7.94e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-30-07+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-16-25+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# Batch size: 8
# 100% 728/728 [12:31<00:00,  1.03s/it, train_loss=2.45]
# Batch size: 8
# 100% 55/55 [01:07<00:00,  1.22s/it]
# speechbrain.utils.train_logger - Epoch: 4, lr: 8.10e-05 - train loss: 2.45 - valid loss: 18.72, valid error_rate: 7.71e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-43-52+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-30-07+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# Batch size: 8
# 100% 728/728 [12:30<00:00,  1.03s/it, train_loss=3.04]
# Batch size: 8
# 100% 55/55 [01:07<00:00,  1.22s/it]
# speechbrain.nnet.schedulers - Changing lr from 8.1e-05 to 7.3e-05
# speechbrain.utils.train_logger - Epoch: 5, lr: 8.10e-05 - train loss: 3.04 - valid loss: 8.18, valid error_rate: 7.73e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-57-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-43-52+00
# speechbrain.utils.epoch_loop - Going into epoch 6
# Batch size: 8
# 100% 728/728 [14:19<00:00,  1.18s/it, train_loss=2.47]
# Batch size: 8
# 100% 55/55 [01:07<00:00,  1.22s/it]
# speechbrain.nnet.schedulers - Changing lr from 7.3e-05 to 6.6e-05
# speechbrain.utils.train_logger - Epoch: 6, lr: 7.29e-05 - train loss: 2.47 - valid loss: 9.18, valid error_rate: 7.73e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-13-11+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+20-57-37+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# Batch size: 8
# 100% 728/728 [12:25<00:00,  1.02s/it, train_loss=1.81]
# Batch size: 8
# 100% 55/55 [01:10<00:00,  1.27s/it]
# speechbrain.utils.train_logger - Epoch: 7, lr: 6.56e-05 - train loss: 1.81 - valid loss: 5.43, valid error_rate: 7.19e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-26-54+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-13-11+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# Batch size: 8
# 100% 728/728 [14:20<00:00,  1.18s/it, train_loss=2.31]
# Batch size: 8
# 100% 55/55 [01:12<00:00,  1.32s/it]
# speechbrain.utils.train_logger - Epoch: 8, lr: 6.56e-05 - train loss: 2.31 - valid loss: 8.64, valid error_rate: 7.16e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-42-33+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-26-54+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# Batch size: 8
# 100% 728/728 [13:14<00:00,  1.09s/it, train_loss=1.58]
# Batch size: 8
# 100% 55/55 [01:06<00:00,  1.21s/it]
# speechbrain.nnet.schedulers - Changing lr from 6.6e-05 to 5.9e-05
# speechbrain.utils.train_logger - Epoch: 9, lr: 6.56e-05 - train loss: 1.58 - valid loss: 6.97, valid error_rate: 7.76e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-57-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-42-33+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# Batch size: 8
# 100% 728/728 [14:47<00:00,  1.22s/it, train_loss=2]
# Batch size: 8
# 100% 55/55 [01:05<00:00,  1.19s/it]
# speechbrain.nnet.schedulers - Changing lr from 5.9e-05 to 5.3e-05
# speechbrain.utils.train_logger - Epoch: 10, lr: 5.90e-05 - train loss: 2.00 - valid loss: 8.90, valid error_rate: 7.83e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-13-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+21-57-00+00
# speechbrain.utils.epoch_loop - Going into epoch 11
# Batch size: 8
# 100% 728/728 [14:12<00:00,  1.17s/it, train_loss=1.57]
# Batch size: 8
# 100% 55/55 [01:01<00:00,  1.12s/it]
# speechbrain.utils.train_logger - Epoch: 11, lr: 5.31e-05 - train loss: 1.57 - valid loss: 6.48, valid error_rate: 6.82e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-28-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-13-00+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# Batch size: 8
# 100% 728/728 [14:34<00:00,  1.20s/it, train_loss=1.71]
# Batch size: 8
# 100% 55/55 [01:07<00:00,  1.22s/it]
# speechbrain.nnet.schedulers - Changing lr from 5.3e-05 to 4.8e-05
# speechbrain.utils.train_logger - Epoch: 12, lr: 5.31e-05 - train loss: 1.71 - valid loss: 10.11, valid error_rate: 8.01e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-44-04+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-28-16+00
# speechbrain.utils.epoch_loop - Going into epoch 13
# Batch size: 8
# 100% 728/728 [15:02<00:00,  1.24s/it, train_loss=1.58]
# Batch size: 8
# 100% 55/55 [01:10<00:00,  1.27s/it]
# speechbrain.utils.train_logger - Epoch: 13, lr: 4.78e-05 - train loss: 1.58 - valid loss: 7.37, valid error_rate: 7.71e-01
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+23-00-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /content/accent-recog-slt2022/CommonAccent/results/ECAPA-TDNN/DE/spkrec-ecapa-voxceleb/1988/save/CKPT+2024-06-17+22-44-04+00
# speechbrain.utils.epoch_loop - Going into epoch 14
# Batch size: 8
#  31% 226/728 [04:55<09:15,  1.11s/it, train_loss=1.4]

# %% [markdown]
# # Training 2 - Hyperparameter Change 1
#
# *
# Hyperparameters changed:
#
# ```
# number_of_epochs: 10
# ```

# %%
# !./run_accent_id_ecapa_tdnn_de.sh

# %% [markdown]
# # Training 3 - Hyperparameter Change 2
#
# *
# Hyperparameters changed (set back of number_of_epochs to 30, changed learning rate):
#
# ```
# number_of_epochs: 30
# # Learning rates
# lr: 0.0005
# ```

# %%
# !./run_accent_id_ecapa_tdnn_de.sh

# %% [markdown]
# # Training 4 - Hyperparameter Change 3
#
# *
# Hyperparameters changed (decrease number_of_epochs AND increaase learning rate):
#
# ```
# number_of_epochs: 10
# # Learning rates
# lr: 0.0005
# ```

# %%
# !./run_accent_id_ecapa_tdnn_de.sh
